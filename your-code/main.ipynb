# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y)
plt.plot(x,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
f, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True)
ax1.plot(x, y)
ax2.plot(x, z)
# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=0)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig,[ax1,ax2] = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(10,5))
plt.subplots_adjust(wspace = 0.4)
ax1.plot(x,y)
ax2.plot(x,z)
plt.show(fig)

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
fig2, [ax1,ax2] = plt.subplots(2, sharey=True, sharex=True, )
x = np.arange(1,50)
y = x**2
z = np.exp(x)
plt.xscale('log')
plt.yscale('log')
ax1.plot(x,y)
ax2.plot(x,z)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig2, [ax1,ax2] = plt.subplots(2, sharey=True, sharex=True, )
x = np.arange(1,50)
y = x**2
z = np.exp(x)
plt.xscale('log')
plt.yscale('log')
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
ax1.plot(x,y)
ax2.plot(x,z)
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
import pandas as pd
fitbit = pd.read_csv('Fitbit2.csv')
fitbit.head(10)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
# 5  2015-05-13             276    779      5.79      15            726.000
# 6  2015-05-14            2687   5614      4.17       2            782.000
# 7  2015-05-15            2793   8169      6.07      14            801.000
# 8  2015-05-16            4061  19971     14.84      18            532.000
# 9  2015-05-17            3349    852      6.33      12            606.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
# 5                     172                     34                   18
# 6                     216                     13                    1
# 7                     218                      8                    7
# 8                     247                    101                  118
# 9                     186                     46                   73
#
#    Activity Calories  ...  Distance_miles       Days  Days_encoded  \
# 0               1680  ...        0.403891     Friday           4.0
# 1               2248  ...        8.767545   Saturday           5.0
# 2               1719  ...        6.567891     Sunday           6.0
# 3               9620  ...        3.119282     Monday           0.0
# 4               7360  ...        2.317714    Tuesday           1.0
# 5               1094  ...        3.597738  Wednesday           2.0
# 6               9830  ...        2.591117   Thursday           3.0
# 7               1092  ...        3.771722     Friday           4.0
# 8                 27  ...        9.221146   Saturday           5.0
# 9               1766  ...        3.933278     Sunday           6.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# 0                1     6.400000        92.086331         0.000000
# 1                0     7.566667        92.464358         6.400000
# 2                0     6.450000        88.761468         7.566667
# 3                1     5.183333        88.857143         6.450000
# 4                1     6.783333        82.892057         5.183333
# 5                1     6.750000        88.621444         6.783333
# 6                1     6.350000        91.807229         6.750000
# 7                1     4.483333        87.908497         6.350000
# 8                0     7.533333        89.151874         4.483333
# 9                0     4.483333        92.439863         7.533333
#
#    Yesterday_sleep_efficiency  Months  Months_encoded
# 0                    0.000000     May               5
# 1                   92.086331     May               5
# 2                   92.464358     May               5
# 3                   88.761468     May               5
# 4                   88.857143     May               5
# 5                   82.892057     May               5
# 6                   88.621444     May               5
# 7                   91.807229     May               5
# 8                   87.908497     May               5
# 9                   89.151874     May               5
#
# [10 rows x 24 columns]

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbit_means = fitbit.groupby(['Months']).mean()

fitbit_means['Months'] = fitbit_means.index
fitbit_means = fitbit_means.sort_values(by=['Months_encoded'])
fitbit_means
# Out:
#            Calorie burned         Steps   Distance     Floors  \
# Months
# January       2812.806452   9892.064516   7.912581   8.580645
# February      2600.100000   8922.866667   7.143667   9.666667
# March         2281.258065  10312.935484   9.184194   9.935484
# April         3030.800000  13079.033333  11.190667  11.566667
# May           2836.580645  10620.096774   8.799677  10.741935
# June          2971.666667  12536.166667  10.881667  24.366667
# July          2699.935484   9193.322581   8.695484  16.000000
# August        2844.967742  11584.774194   9.059677  14.129032
# September     2908.000000   9191.333333   7.836333  12.266667
# October       2608.838710   8272.451613   6.570000   6.709677
# November      2578.066667   9467.466667   7.927333   8.033333
# December      2737.290323   8470.064516   7.460323   8.935484
#
#            Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# Months
# January           573.702000              249.838710              27.548387
# February          598.077133              214.933333              25.166667
# March             490.865000              220.935484              13.096774
# April             638.469700              293.866667              13.800000
# May               654.149161              229.580645              28.258065
# June              655.641500              237.766667              33.600000
# July              644.071323              240.967742              33.161290
# August            497.499000              265.322581              25.903226
# September         535.728967              233.233333              32.700000
# October           447.882871              195.387097              26.967742
# November          509.027167              219.566667              34.166667
# December          525.882935              236.032258              19.870968
#
#            Minutes Very Active  Activity Calories  MinutesOfSleep  ...  \
# Months                                                             ...
# January              27.387097        1705.741935      310.516129  ...
# February             25.033333        1833.033333      269.933333  ...
# March                41.451613        2443.387097      242.290323  ...
# April                48.866667        1710.333333      322.133333  ...
# May                  46.806452        3391.419355      353.612903  ...
# June                 60.866667        1686.400000      354.800000  ...
# July                 37.419355        1734.967742      347.161290  ...
# August               28.516129        1502.483871      333.387097  ...
# September            29.033333        1862.033333      259.700000  ...
# October              18.645161        3004.354839      208.709677  ...
# November             35.666667        2121.233333      247.500000  ...
# December             29.645161        1501.870968      236.064516  ...
#
#            LengthOfRestInMinutes  Distance_miles  Days_encoded  \
# Months
# January               340.161290        4.916648      3.193548
# February              294.600000        4.438867      2.933333
# March                 265.387097        5.706792      2.903226
# April                 357.766667        6.953556      3.100000
# May                   394.935484        5.467864      3.193548
# June                  399.266667        6.761552      2.833333
# July                  385.387097        5.403122      3.000000
# August                368.903226        5.629421      3.064516
# September             288.633333        4.869270      2.900000
# October               230.258065        4.082407      3.096774
# November              271.900000        4.925815      3.000000
# December              259.096774        4.635628      2.903226
#
#            Work_or_Weekend  Hours Sleep  Sleep efficiency  Yesterday_sleep  \
# Months
# January           0.677419     5.175269         79.535533         5.245699
# February          0.733333     4.498889         73.325942         4.605000
# March             0.741935     4.038172         70.799130         3.955914
# April             0.700000     5.368889         84.023962         5.293889
# May               0.677419     5.893548         86.669604         5.638710
# June              0.733333     5.913333         85.083234         5.939444
# July              0.741935     5.786022         86.959627         5.764516
# August            0.677419     5.556452         84.537428         5.568280
# September         0.733333     4.328333         65.660698         4.307778
# October           0.709677     3.478495         64.688161         3.590323
# November          0.700000     4.125000         66.948579         4.212222
# December          0.741935     3.934409         67.903253         3.709140
#
#            Yesterday_sleep_efficiency  Months_encoded     Months
# Months
# January                     79.545673             1.0    January
# February                    73.287582             2.0   February
# March                       70.782667             3.0      March
# April                       84.100439             4.0      April
# May                         83.934522             5.0        May
# June                        84.943985             6.0       June
# July                        87.054673             7.0       July
# August                      84.422750             8.0     August
# September                   65.604344             9.0  September
# October                     64.757106            10.0    October
# November                    66.722475            11.0   November
# December                    68.090263            12.0   December
#
# [12 rows x 22 columns]

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
plt.figure(figsize=(12,4))
#fitbit_means[['Months','Steps']].plot()

plt.bar(fitbit_means['Months'],fitbit_means['Steps'])
plt.savefig('steps_by_month.png')
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

# %%
fitbit_means = fitbit.groupby(['Work_or_Weekend']).mean()

fitbit_means
# Out:
#                  Calorie burned         Steps  Distance     Floors  \
# Work_or_Weekend
# 0                   2647.628571  10064.238095  8.175619   6.885714
# 1                   2779.122137  10144.572519  8.698817  13.664122
#
#                  Minutes Sedentary  Minutes Lightly Active  \
# Work_or_Weekend
# 0                       530.831171              263.419048
# 1                       577.201076              225.580153
#
#                  Minutes Fairly Active  Minutes Very Active  \
# Work_or_Weekend
# 0                            22.628571            30.638095
# 1                            27.580153            37.759542
#
#                  Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  \
# Work_or_Weekend
# 0                      1901.523810      267.495238            26.895238
# 1                      2101.305344      299.690840            28.454198
#
#                  NumberOfAwakings  LengthOfRestInMinutes  Distance_miles  \
# Work_or_Weekend
# 0                       15.609524             297.523810        5.080093
# 1                       16.431298             330.889313        5.405192
#
#                  Days_encoded  Hours Sleep  Sleep efficiency  Yesterday_sleep  \
# Work_or_Weekend
# 0                    5.495238     4.458254         74.683679         4.606190
# 1                    2.015267     4.994847         77.035729         4.903626
#
#                  Yesterday_sleep_efficiency  Months_encoded
# Work_or_Weekend
# 0                                 75.650482        6.447619
# 1                                 76.307944        6.522901

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
